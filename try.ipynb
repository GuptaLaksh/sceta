# %%
import importlib
import clusterparams
importlib.reload(clusterparams)
dfparams = clusterparams.initialize()
hold = dfparams['dfparams'][dfparams['dfparams']['ID'] == 'ngc2808']
print(hold)
# Out:
#          ID  [Fe/H]  E(B-V)  (m-M)V          RA      DEC
# 15  ngc2808   -1.14    0.22   15.59  138.012917 -64.8635
